# %% [markdown]
# # Hybrid Filtering

# %%
import pandas as pd
import numpy as np
from scipy import sparse
from sklearn.metrics.pairwise import cosine_similarity

import seaborn as sns
import matplotlib.pyplot as plt
import json

# %%
tmdb_movies = pd.read_csv("tmdb-5000-movie-dataset/tmdb_5000_movies.csv")
lens_movies = pd.read_csv("movie-lens-dataset/movies.csv")
credits = pd.read_csv("tmdb-5000-movie-dataset/tmdb_5000_credits.csv")

## add release year to title in tmdb_movies
year = tmdb_movies["release_date"].apply(lambda x: str(x)[:4])
tmdb_movies["title"] = tmdb_movies["title"]+" ("+year+")"
tmdb_movies = tmdb_movies.rename(columns={'id': "movie_id"})
# movies = movies.merge(lens_movies, on="title")

## exchange comma in title in lens_movies
def title_comma_exchange(obj):
    title, year = obj[:-7], obj[-6:]
    title = title.split(",")
    if title[-1]!= title[0]:
        new_title = title[-1]+" "+title[0]
        return new_title[1:]+" "+year
    else:
        return obj

lens_movies["title"] = lens_movies["title"].apply(title_comma_exchange)

# %%
movies = pd.merge(tmdb_movies, lens_movies, on="title")
movies = movies.merge(credits, on="movie_id")

# %%
movies
# Out:
#          budget                                           genres_x  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 3150          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3151      12000  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 3152      20000  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 3153       7000  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 3154     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                           homepage  movie_id  \
# 0                      http://www.avatarmovie.com/     19995
# 1     http://disney.go.com/disneypictures/pirates/       285
# 2      http://www.sonypictures.com/movies/spectre/    206647
# 3               http://www.thedarkknightrises.com/     49026
# 4             http://movies.disney.com/john-carter     49529
# ...                                            ...       ...
# 3150                                           NaN     14585
# 3151                                           NaN       692
# 3152                                           NaN     36095
# 3153                    http://www.primermovie.com     14337
# 3154                                           NaN      9367
#
#                                                keywords original_language  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...                en
# 4     [{"id": 818, "name": "based on novel"}, {"id":...                en
# ...                                                 ...               ...
# 3150  [{"id": 1438, "name": "office"}, {"id": 9673, ...                en
# 3151  [{"id": 237, "name": "gay"}, {"id": 900, "name...                en
# 3152  [{"id": 233, "name": "japan"}, {"id": 549, "na...                ja
# 3153  [{"id": 1448, "name": "distrust"}, {"id": 2101...                en
# 3154  [{"id": 5616, "name": "united states\u2013mexi...                es
#
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 3150                     In the Company of Men
# 3151                            Pink Flamingos
# 3152                                       キュア
# 3153                                    Primer
# 3154                               El Mariachi
#
#                                                overview  popularity  \
# 0     In the 22nd century, a paraplegic Marine is di...  150.437577
# 1     Captain Barbossa, long believed to be dead, ha...  139.082615
# 2     A cryptic message from Bond’s past sends him o...  107.376788
# 3     Following the death of District Attorney Harve...  112.312950
# 4     John Carter is a war-weary, former military ca...   43.926995
# ...                                                 ...         ...
# 3150  Two business executives--one an avowed misogyn...    2.634007
# 3151  Notorious Baltimore criminal and underground f...    4.553644
# 3152  A wave of gruesome murders is sweeping Tokyo. ...    0.212443
# 3153  Friends/fledgling entrepreneurs invent a devic...   23.307949
# 3154  El Mariachi just wants to play his guitar and ...   14.269792
#
#                                    production_companies  ...    status  \
# 0     [{"name": "Ingenious Film Partners", "id": 289...  ...  Released
# 1     [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...  Released
# 2     [{"name": "Columbia Pictures", "id": 5}, {"nam...  ...  Released
# 3     [{"name": "Legendary Pictures", "id": 923}, {"...  ...  Released
# 4           [{"name": "Walt Disney Pictures", "id": 2}]  ...  Released
# ...                                                 ...  ...       ...
# 3150  [{"name": "Alliance Atlantis Communications", ...  ...  Released
# 3151     [{"name": "Dreamland Productions", "id": 407}]  ...  Released
# 3152             [{"name": "Daiei Studios", "id": 881}]  ...  Released
# 3153                 [{"name": "Thinkfilm", "id": 446}]  ...  Released
# 3154           [{"name": "Columbia Pictures", "id": 5}]  ...  Released
#
#                                                 tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in our world, found in another.
# ...                                                 ...
# 3150      Are all men bastards...or just misunderstood?
# 3151                         An exercise in poor taste.
# 3152                           Madness. Terror. Murder.
# 3153                 What happens if it actually works?
# 3154  He didn't come looking for trouble, but troubl...
#
#                                               title_x  vote_average  \
# 0                                       Avatar (2009)           7.2
# 1     Pirates of the Caribbean: At World's End (2007)           6.9
# 2                                      Spectre (2015)           6.3
# 3                        The Dark Knight Rises (2012)           7.6
# 4                                  John Carter (2012)           6.1
# ...                                               ...           ...
# 3150                     In the Company of Men (1997)           6.8
# 3151                            Pink Flamingos (1972)           6.2
# 3152                                      Cure (1997)           7.4
# 3153                                    Primer (2004)           6.9
# 3154                               El Mariachi (1992)           6.6
#
#      vote_count movieId                         genres_y  \
# 0         11800   72998     Action|Adventure|Sci-Fi|IMAX
# 1          4500   53125  Action|Adventure|Comedy|Fantasy
# 2          4466  136020           Action|Adventure|Crime
# 3          9106   91529      Action|Adventure|Crime|IMAX
# 4          2124   93363     Action|Adventure|Sci-Fi|IMAX
# ...         ...     ...                              ...
# 3150         44    1594                     Comedy|Drama
# 3151        110    2361                           Comedy
# 3152         63    4645            Crime|Horror|Thriller
# 3153        658    8914                     Drama|Sci-Fi
# 3154        238    3267    Action|Crime|Thriller|Western
#
#                                        title_y  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 3150                     In the Company of Men
# 3151                            Pink Flamingos
# 3152                                      Cure
# 3153                                    Primer
# 3154                               El Mariachi
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 3150  [{"cast_id": 1, "character": "Chad", "credit_i...
# 3151  [{"cast_id": 8, "character": "Divine / Babs Jo...
# 3152  [{"cast_id": 3, "character": "Kenichi Takabe",...
# 3153  [{"cast_id": 1, "character": "Aaron", "credit_...
# 3154  [{"cast_id": 1, "character": "El Mariachi", "c...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 3150  [{"credit_id": "52fe46049251416c7506a36b", "de...
# 3151  [{"credit_id": "52fe426bc3a36847f801d203", "de...
# 3152  [{"credit_id": "52fe45cc9251416c9103eb7b", "de...
# 3153  [{"credit_id": "52fe45e79251416c75066791", "de...
# 3154  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
#
# [3155 rows x 25 columns]

# %% [markdown]
# ## *Feature Selection and Preprocessing*

# %% [markdown]
# ### *Important Features*

# %% [markdown]
# 1. id
# 2. title
# 3. genres
# 5. keywords
# 6. release_date
# 7. overview
# 9. cast
# 10. crew

# %%
movies = movies[["movie_id", "title_x", "release_date", "overview", "genres_x", "keywords", "cast", "crew"]]
movies = movies.rename(columns={"title_x": "title"})
movies = movies.rename(columns={"genres_x": "genres"})

# %%
movies
# Out:
#       movie_id                                            title release_date  \
# 0        19995                                    Avatar (2009)   2009-12-10
# 1          285  Pirates of the Caribbean: At World's End (2007)   2007-05-19
# 2       206647                                   Spectre (2015)   2015-10-26
# 3        49026                     The Dark Knight Rises (2012)   2012-07-16
# 4        49529                               John Carter (2012)   2012-03-07
# ...        ...                                              ...          ...
# 3150     14585                     In the Company of Men (1997)   1997-01-19
# 3151       692                            Pink Flamingos (1972)   1972-03-12
# 3152     36095                                      Cure (1997)   1997-11-06
# 3153     14337                                    Primer (2004)   2004-10-08
# 3154      9367                               El Mariachi (1992)   1992-09-04
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# 3     Following the death of District Attorney Harve...
# 4     John Carter is a war-weary, former military ca...
# ...                                                 ...
# 3150  Two business executives--one an avowed misogyn...
# 3151  Notorious Baltimore criminal and underground f...
# 3152  A wave of gruesome murders is sweeping Tokyo. ...
# 3153  Friends/fledgling entrepreneurs invent a devic...
# 3154  El Mariachi just wants to play his guitar and ...
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...                                                 ...
# 3150  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3151  [{"id": 27, "name": "Horror"}, {"id": 35, "nam...
# 3152  [{"id": 80, "name": "Crime"}, {"id": 27, "name...
# 3153  [{"id": 878, "name": "Science Fiction"}, {"id"...
# 3154  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
#
#                                                keywords  \
# 0     [{"id": 1463, "name": "culture clash"}, {"id":...
# 1     [{"id": 270, "name": "ocean"}, {"id": 726, "na...
# 2     [{"id": 470, "name": "spy"}, {"id": 818, "name...
# 3     [{"id": 849, "name": "dc comics"}, {"id": 853,...
# 4     [{"id": 818, "name": "based on novel"}, {"id":...
# ...                                                 ...
# 3150  [{"id": 1438, "name": "office"}, {"id": 9673, ...
# 3151  [{"id": 237, "name": "gay"}, {"id": 900, "name...
# 3152  [{"id": 233, "name": "japan"}, {"id": 549, "na...
# 3153  [{"id": 1448, "name": "distrust"}, {"id": 2101...
# 3154  [{"id": 5616, "name": "united states\u2013mexi...
#
#                                                    cast  \
# 0     [{"cast_id": 242, "character": "Jake Sully", "...
# 1     [{"cast_id": 4, "character": "Captain Jack Spa...
# 2     [{"cast_id": 1, "character": "James Bond", "cr...
# 3     [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     [{"cast_id": 5, "character": "John Carter", "c...
# ...                                                 ...
# 3150  [{"cast_id": 1, "character": "Chad", "credit_i...
# 3151  [{"cast_id": 8, "character": "Divine / Babs Jo...
# 3152  [{"cast_id": 3, "character": "Kenichi Takabe",...
# 3153  [{"cast_id": 1, "character": "Aaron", "credit_...
# 3154  [{"cast_id": 1, "character": "El Mariachi", "c...
#
#                                                    crew
# 0     [{"credit_id": "52fe48009251416c750aca23", "de...
# 1     [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2     [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3     [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4     [{"credit_id": "52fe479ac3a36847f813eaa3", "de...
# ...                                                 ...
# 3150  [{"credit_id": "52fe46049251416c7506a36b", "de...
# 3151  [{"credit_id": "52fe426bc3a36847f801d203", "de...
# 3152  [{"credit_id": "52fe45cc9251416c9103eb7b", "de...
# 3153  [{"credit_id": "52fe45e79251416c75066791", "de...
# 3154  [{"credit_id": "52fe44eec3a36847f80b280b", "de...
#
# [3155 rows x 8 columns]

# %%
movies.isnull().sum()
# Out:
# movie_id        0
# title           0
# release_date    0
# overview        0
# genres          0
# keywords        0
# cast            0
# crew            0
# dtype: int64

# %%
movies.dropna(inplace=True)

# %%
movies.duplicated().sum()
# Out:
# 2

# %% [markdown]
# ### *Convert genres and keywords*

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def convert_genres(obj):
    L = []
    for i in json.loads(obj):
        L.append(i["name"])
    return L

# %%
# convert_to_list(movies.iloc[0].genres)

# %%
movies["genres"] = movies["genres"].apply(convert_genres)
movies["keywords"] = movies["keywords"].apply(convert_genres)

# %%
movies.head()
# Out:
#    movie_id                                            title release_date  \
# 0     19995                                    Avatar (2009)   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End (2007)   2007-05-19
# 2    206647                                   Spectre (2015)   2015-10-26
# 3     49026                     The Dark Knight Rises (2012)   2012-07-16
# 4     49529                               John Carter (2012)   2012-03-07
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# ### *Convert cast*

# %%
def convert_cast(obj):
    L = []
    counter = 0
    for i in json.loads(obj):
        if counter == 3:
            break
        else:
            counter+=1
            L.append(i["name"])
    return L

# %%
movies["cast"] = movies["cast"].apply(convert_cast)

# %%
movies.head()
# Out:
#    movie_id                                            title release_date  \
# 0     19995                                    Avatar (2009)   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End (2007)   2007-05-19
# 2    206647                                   Spectre (2015)   2015-10-26
# 3     49026                     The Dark Knight Rises (2012)   2012-07-16
# 4     49529                               John Carter (2012)   2012-03-07
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]
# 3      [Christian Bale, Michael Caine, Gary Oldman]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %% [markdown]
# ### *Convert crew*

# %%
def convert_crew(obj):
    L = []
    for i in json.loads(obj):
        if i["job"] == "Director":
            L.append(i["name"])
    return L

# %%
movies["crew"] = movies["crew"].apply(convert_crew)

# %%
movies.head()
# Out:
#    movie_id                                            title release_date  \
# 0     19995                                    Avatar (2009)   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End (2007)   2007-05-19
# 2    206647                                   Spectre (2015)   2015-10-26
# 3     49026                     The Dark Knight Rises (2012)   2012-07-16
# 4     49529                               John Carter (2012)   2012-03-07
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %% [markdown]
# ### *Convert Overview*

# %%
movies["overview"] = movies["overview"].apply(lambda x:x.split())

# %%
movies.head()
# Out:
#    movie_id                                            title release_date  \
# 0     19995                                    Avatar (2009)   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End (2007)   2007-05-19
# 2    206647                                   Spectre (2015)   2015-10-26
# 3     49026                     The Dark Knight Rises (2012)   2012-07-16
# 4     49529                               John Carter (2012)   2012-03-07
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                                cast                 crew
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weaver]      [James Cameron]
# 1     [Johnny Depp, Orlando Bloom, Keira Knightley]     [Gore Verbinski]
# 2      [Daniel Craig, Christoph Waltz, Léa Seydoux]         [Sam Mendes]
# 3      [Christian Bale, Michael Caine, Gary Oldman]  [Christopher Nolan]
# 4    [Taylor Kitsch, Lynn Collins, Samantha Morton]     [Andrew Stanton]

# %% [markdown]
# ## *Remove spaces*

# %%
movies["overview"] = movies["overview"].apply(lambda x:[i.replace(" ","") for i in x])
movies["genres"] = movies["genres"].apply(lambda x:[i.replace(" ","") for i in x])
movies["keywords"] = movies["keywords"].apply(lambda x:[i.replace(" ","") for i in x])
movies["cast"] = movies["cast"].apply(lambda x:[i.replace(" ","") for i in x])
movies["crew"] = movies["crew"].apply(lambda x:[i.replace(" ","") for i in x])

# %%
movies.head()
# Out:
#    movie_id                                            title release_date  \
# 0     19995                                    Avatar (2009)   2009-12-10
# 1       285  Pirates of the Caribbean: At World's End (2007)   2007-05-19
# 2    206647                                   Spectre (2015)   2015-10-26
# 3     49026                     The Dark Knight Rises (2012)   2012-07-16
# 4     49529                               John Carter (2012)   2012-03-07
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
#                                             keywords  \
# 0  [cultureclash, future, spacewar, spacecolony, ...
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...
# 2  [spy, basedonnovel, secretagent, sequel, mi6, ...
# 3  [dccomics, crimefighter, terrorist, secretiden...
# 4  [basedonnovel, mars, medallion, spacetravel, p...
#
#                                             cast                crew
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver]      [JamesCameron]
# 1     [JohnnyDepp, OrlandoBloom, KeiraKnightley]     [GoreVerbinski]
# 2      [DanielCraig, ChristophWaltz, LéaSeydoux]         [SamMendes]
# 3      [ChristianBale, MichaelCaine, GaryOldman]  [ChristopherNolan]
# 4    [TaylorKitsch, LynnCollins, SamanthaMorton]     [AndrewStanton]

# %% [markdown]
# ## *Combine columns: overview, genres, keywords, cast & crew*

# %%
# movies.head()

# %%
movies["tags"] = movies["overview"] + movies["genres"] + movies["keywords"] + movies["cast"] + movies["crew"]

# %%
new_df = movies[["movie_id", "title", "tags"]]
new_df.head()
# Out:
#    movie_id                                            title  \
# 0     19995                                    Avatar (2009)
# 1       285  Pirates of the Caribbean: At World's End (2007)
# 2    206647                                   Spectre (2015)
# 3     49026                     The Dark Knight Rises (2012)
# 4     49529                               John Carter (2012)
#
#                                                 tags
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...

# %%
new_df["tags"] = new_df["tags"].apply(lambda x:" ".join(x))
new_df["tags"] = new_df["tags"].apply(lambda x: x.lower())
# Out:
# /tmp/ipykernel_10071/3576936435.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"] = new_df["tags"].apply(lambda x:" ".join(x))
# /tmp/ipykernel_10071/3576936435.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"] = new_df["tags"].apply(lambda x: x.lower())

# %%
new_df.head()
# Out:
#    movie_id                                            title  \
# 0     19995                                    Avatar (2009)
# 1       285  Pirates of the Caribbean: At World's End (2007)
# 2    206647                                   Spectre (2015)
# 3     49026                     The Dark Knight Rises (2012)
# 4     49529                               John Carter (2012)
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
new_df["tags"][0]
# Out:
# 'in the 22nd century, a paraplegic marine is dispatched to the moon pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. action adventure fantasy sciencefiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d samworthington zoesaldana sigourneyweaver jamescameron'

# %% [markdown]
# ## *Stem contents of tags with NLTK*

# %%
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

# %%
def stem(text):
    ret = []
    words = text.split(" ")
    for word in words:
        ret.append(stemmer.stem(word))
    return " ".join(ret)

# %%
new_df["tags"] = new_df["tags"].apply(stem)
# Out:
# /tmp/ipykernel_10071/825579503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["tags"] = new_df["tags"].apply(stem)

# %% [markdown]
# ## *Vectorize movie tags data*

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words="english")

# %%
vectors = cv.fit_transform(new_df["tags"]).toarray()

# %%
vectors.shape
# Out:
# (3155, 5000)

# %%
# for i in cv.get_feature_names_out():
    # print(i)

# %% [markdown]
# ## *Measure Cosine Similarity*

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_matrix = cosine_similarity(vectors)

# %%
similarity_matrix = pd.DataFrame(similarity_matrix, index=movies['title'], columns=movies['title'])

# %%
similarity_matrix
# Out:
# title                                            Avatar (2009)  \
# title
# Avatar (2009)                                         1.000000
# Pirates of the Caribbean: At World's End (2007)       0.079057
# Spectre (2015)                                        0.083853
# The Dark Knight Rises (2012)                          0.069007
# John Carter (2012)                                    0.186501
# ...                                                        ...
# In the Company of Men (1997)                          0.000000
# Pink Flamingos (1972)                                 0.000000
# Cure (1997)                                           0.000000
# Primer (2004)                                         0.050637
# El Mariachi (1992)                                    0.018765
#
# title                                            Pirates of the Caribbean: At World's End (2007)  \
# title
# Avatar (2009)                                                                           0.079057
# Pirates of the Caribbean: At World's End (2007)                                         1.000000
# Spectre (2015)                                                                          0.058926
# The Dark Knight Rises (2012)                                                            0.036370
# John Carter (2012)                                                                      0.073721
# ...                                                                                          ...
# In the Company of Men (1997)                                                            0.032075
# Pink Flamingos (1972)                                                                   0.000000
# Cure (1997)                                                                             0.023810
# Primer (2004)                                                                           0.026688
# El Mariachi (1992)                                                                      0.039559
#
# title                                            Spectre (2015)  \
# title
# Avatar (2009)                                          0.083853
# Pirates of the Caribbean: At World's End (2007)        0.058926
# Spectre (2015)                                         1.000000
# The Dark Knight Rises (2012)                           0.057864
# John Carter (2012)                                     0.078193
# ...                                                         ...
# In the Company of Men (1997)                           0.000000
# Pink Flamingos (1972)                                  0.063500
# Cure (1997)                                            0.075761
# Primer (2004)                                          0.000000
# El Mariachi (1992)                                     0.041959
#
# title                                            The Dark Knight Rises (2012)  \
# title
# Avatar (2009)                                                        0.069007
# Pirates of the Caribbean: At World's End (2007)                      0.036370
# Spectre (2015)                                                       0.057864
# The Dark Knight Rises (2012)                                         1.000000
# John Carter (2012)                                                   0.032174
# ...                                                                       ...
# In the Company of Men (1997)                                         0.020998
# Pink Flamingos (1972)                                                0.039193
# Cure (1997)                                                          0.093522
# Primer (2004)                                                        0.052414
# El Mariachi (1992)                                                   0.064744
#
# title                                            John Carter (2012)  \
# title
# Avatar (2009)                                              0.186501
# Pirates of the Caribbean: At World's End (2007)            0.073721
# Spectre (2015)                                             0.078193
# The Dark Knight Rises (2012)                               0.032174
# John Carter (2012)                                         1.000000
# ...                                                             ...
# In the Company of Men (1997)                               0.056750
# Pink Flamingos (1972)                                      0.000000
# Cure (1997)                                                0.042126
# Primer (2004)                                              0.023610
# El Mariachi (1992)                                         0.157483
#
# title                                            Spider-Man 3 (2007)  \
# title
# Avatar (2009)                                               0.107583
# Pirates of the Caribbean: At World's End (2007)             0.113402
# Spectre (2015)                                              0.072169
# The Dark Knight Rises (2012)                                0.059391
# John Carter (2012)                                          0.100322
# ...                                                              ...
# In the Company of Men (1997)                                0.104757
# Pink Flamingos (1972)                                       0.024441
# Cure (1997)                                                 0.019440
# Primer (2004)                                               0.043581
# El Mariachi (1992)                                          0.080750
#
# title                                            Tangled (2010)  \
# title
# Avatar (2009)                                          0.039528
# Pirates of the Caribbean: At World's End (2007)        0.020833
# Spectre (2015)                                         0.022097
# The Dark Knight Rises (2012)                           0.054554
# John Carter (2012)                                     0.055291
# ...                                                         ...
# In the Company of Men (1997)                           0.024056
# Pink Flamingos (1972)                                  0.000000
# Cure (1997)                                            0.017857
# Primer (2004)                                          0.020016
# El Mariachi (1992)                                     0.029670
#
# title                                            Avengers: Age of Ultron (2015)  \
# title
# Avatar (2009)                                                          0.141421
# Pirates of the Caribbean: At World's End (2007)                        0.124226
# Spectre (2015)                                                         0.131762
# The Dark Knight Rises (2012)                                           0.065060
# John Carter (2012)                                                     0.197814
# ...                                                                         ...
# In the Company of Men (1997)                                           0.028689
# Pink Flamingos (1972)                                                  0.000000
# Cure (1997)                                                            0.000000
# Primer (2004)                                                          0.071611
# El Mariachi (1992)                                                     0.141532
#
# title                                            Harry Potter and the Half-Blood Prince (2009)  \
# title
# Avatar (2009)                                                                         0.056796
# Pirates of the Caribbean: At World's End (2007)                                       0.059868
# Spectre (2015)                                                                        0.063500
# The Dark Knight Rises (2012)                                                          0.039193
# John Carter (2012)                                                                    0.079444
# ...                                                                                        ...
# In the Company of Men (1997)                                                          0.034565
# Pink Flamingos (1972)                                                                 0.000000
# Cure (1997)                                                                           0.000000
# Primer (2004)                                                                         0.028760
# El Mariachi (1992)                                                                    0.127891
#
# title                                            Batman v Superman: Dawn of Justice (2016)  \
# title
# Avatar (2009)                                                                     0.093250
# Pirates of the Caribbean: At World's End (2007)                                   0.098295
# Spectre (2015)                                                                    0.104257
# The Dark Knight Rises (2012)                                                      0.193047
# John Carter (2012)                                                                0.108696
# ...                                                                                    ...
# In the Company of Men (1997)                                                      0.028375
# Pink Flamingos (1972)                                                             0.000000
# Cure (1997)                                                                       0.000000
# Primer (2004)                                                                     0.000000
# El Mariachi (1992)                                                                0.034996
#
# title                                            ...  The Signal (2014)  \
# title                                            ...
# Avatar (2009)                                    ...           0.026726
# Pirates of the Caribbean: At World's End (2007)  ...           0.028172
# Spectre (2015)                                   ...           0.000000
# The Dark Knight Rises (2012)                     ...           0.055328
# John Carter (2012)                               ...           0.024922
# ...                                              ...                ...
# In the Company of Men (1997)                     ...           0.032530
# Pink Flamingos (1972)                            ...           0.060718
# Cure (1997)                                      ...           0.048295
# Primer (2004)                                    ...           0.108266
# El Mariachi (1992)                               ...           0.040121
#
# title                                            George Washington (2000)  \
# title
# Avatar (2009)                                                    0.000000
# Pirates of the Caribbean: At World's End (2007)                  0.000000
# Spectre (2015)                                                   0.000000
# The Dark Knight Rises (2012)                                     0.054554
# John Carter (2012)                                               0.000000
# ...                                                                   ...
# In the Company of Men (1997)                                     0.096225
# Pink Flamingos (1972)                                            0.044901
# Cure (1997)                                                      0.000000
# Primer (2004)                                                    0.080064
# El Mariachi (1992)                                               0.059339
#
# title                                            The Last Waltz (1978)  \
# title
# Avatar (2009)                                                 0.000000
# Pirates of the Caribbean: At World's End (2007)               0.000000
# Spectre (2015)                                                0.000000
# The Dark Knight Rises (2012)                                  0.000000
# John Carter (2012)                                            0.000000
# ...                                                                ...
# In the Company of Men (1997)                                  0.000000
# Pink Flamingos (1972)                                         0.000000
# Cure (1997)                                                   0.031174
# Primer (2004)                                                 0.000000
# El Mariachi (1992)                                            0.000000
#
# title                                            Down Terrace (2009)  \
# title
# Avatar (2009)                                               0.055902
# Pirates of the Caribbean: At World's End (2007)             0.029463
# Spectre (2015)                                              0.093750
# The Dark Knight Rises (2012)                                0.096440
# John Carter (2012)                                          0.078193
# ...                                                              ...
# In the Company of Men (1997)                                0.068041
# Pink Flamingos (1972)                                       0.127000
# Cure (1997)                                                 0.176777
# Primer (2004)                                               0.028307
# El Mariachi (1992)                                          0.062939
#
# title                                            Clerks (1994)  \
# title
# Avatar (2009)                                         0.000000
# Pirates of the Caribbean: At World's End (2007)       0.037268
# Spectre (2015)                                        0.000000
# The Dark Knight Rises (2012)                          0.000000
# John Carter (2012)                                    0.000000
# ...                                                        ...
# In the Company of Men (1997)                          0.129099
# Pink Flamingos (1972)                                 0.040161
# Cure (1997)                                           0.000000
# Primer (2004)                                         0.035806
# El Mariachi (1992)                                    0.026537
#
# title                                            In the Company of Men (1997)  \
# title
# Avatar (2009)                                                        0.000000
# Pirates of the Caribbean: At World's End (2007)                      0.032075
# Spectre (2015)                                                       0.000000
# The Dark Knight Rises (2012)                                         0.020998
# John Carter (2012)                                                   0.056750
# ...                                                                       ...
# In the Company of Men (1997)                                         1.000000
# Pink Flamingos (1972)                                                0.069130
# Cure (1997)                                                          0.000000
# Primer (2004)                                                        0.061633
# El Mariachi (1992)                                                   0.091358
#
# title                                            Pink Flamingos (1972)  \
# title
# Avatar (2009)                                                 0.000000
# Pirates of the Caribbean: At World's End (2007)               0.000000
# Spectre (2015)                                                0.063500
# The Dark Knight Rises (2012)                                  0.039193
# John Carter (2012)                                            0.000000
# ...                                                                ...
# In the Company of Men (1997)                                  0.069130
# Pink Flamingos (1972)                                         1.000000
# Cure (1997)                                                   0.128290
# Primer (2004)                                                 0.028760
# El Mariachi (1992)                                            0.021315
#
# title                                            Cure (1997)  Primer (2004)  \
# title
# Avatar (2009)                                       0.000000       0.050637
# Pirates of the Caribbean: At World's End (2007)     0.023810       0.026688
# Spectre (2015)                                      0.075761       0.000000
# The Dark Knight Rises (2012)                        0.093522       0.052414
# John Carter (2012)                                  0.042126       0.023610
# ...                                                      ...            ...
# In the Company of Men (1997)                        0.000000       0.061633
# Pink Flamingos (1972)                               0.128290       0.028760
# Cure (1997)                                         1.000000       0.022875
# Primer (2004)                                       0.022875       1.000000
# El Mariachi (1992)                                  0.084770       0.057011
#
# title                                            El Mariachi (1992)
# title
# Avatar (2009)                                              0.018765
# Pirates of the Caribbean: At World's End (2007)            0.039559
# Spectre (2015)                                             0.041959
# The Dark Knight Rises (2012)                               0.064744
# John Carter (2012)                                         0.157483
# ...                                                             ...
# In the Company of Men (1997)                               0.091358
# Pink Flamingos (1972)                                      0.021315
# Cure (1997)                                                0.084770
# Primer (2004)                                              0.057011
# El Mariachi (1992)                                         1.000000
#
# [3155 rows x 3155 columns]

# %% [markdown]
# ## *Make Recommendations*

# %%
def make_rocommendation(movie_name):
    recommended_movies = []
    similar_scores = similarity_matrix[movie_name]
    similar_scores = pd.DataFrame(similarity_matrix[movie_name])
    similar_scores = similar_scores.sort_values(movie_name, ascending=False)[1:11]
    # similar_scores = similar_scores.rename(columns={movie_name: "similarity_index"})
    similar_scores = similar_scores.merge(new_df, on="title")
    for m in similar_scores["title"]:
        recommended_movies.append(m)
    return recommended_movies

# %%
make_rocommendation("The Godfather (1972)")
# Out:
# ['The Godfather: Part II (1974)',
#  'The Godfather: Part III (1990)',
#  'Sexy Beast (2000)',
#  'Road to Perdition (2002)',
#  'Donnie Brasco (1997)',
#  'The Usual Suspects (1995)',
#  'J. Edgar (2011)',
#  'Only God Forgives (2013)',
#  'Idlewild (2006)',
#  'Auto Focus (2002)']

# %%
for mov in movies.title:
    if "God" in mov:
        print(mov)
# Out:
# Shin Godzilla (2016)
# Exodus: Gods and Kings (2014)
# Gods of Egypt (2016)
# Gods and Generals (2003)
# The Godfather: Part III (1990)
# Godsend (2004)
# Son of God (2014)
# The Godfather: Part II (1974)
# The Godfather (1972)
# Only God Forgives (2013)
# Gods and Monsters (1998)

# %%
import pickle

pickle.dump(similarity_matrix, open("similarity_matrix.pkl", "wb"))
pickle.dump(new_df, open("movies.pkl", "wb"))
